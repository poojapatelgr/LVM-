# %%
import pandas as pd

# %%
df=pd.read_csv('/home/sikshana/sw/leaves/leaveapp/text.csv')

# %%
df.head()
# Out:
#        user employee_name  role  rollover           region lm_start_date  \
# 0  archanas         Acchu     1        55  South Karnataka    2021-06-01
# 1    mahesh          Mahi     0        10          Gujarat    2021-07-01
# 2     pooja           Poo     1        22       Maharastra    2021-08-01
#
#    approver approver_id  Gender
# 0         1       pooja    Male
# 1         1    archanas  Female
# 2         1      mahesh    Male

# %%
dfr=pd.read_csv('/home/sikshana/sw/leaves/leaveapp/rec.csv')
dfr
# Out:
#    employee_number  password employee_name  role  rollover           region  \
# 0            12345  20190703        Mahesh     1        77  South Karnataka
# 1             5678  20190703     Archana S     0        66      Maharashtra
# 2            91011  20190703          Ravi     1        55          Gujarat
# 3         12131415  20190703     Archana J     0        44  North Karnataka
#
#   lm_start_date  approver  approver_id  Gender
# 0    2021-06-01         1     12131415    Male
# 1    2021-07-01         1     12131415  Female
# 2    2021-08-01         1     12131415    Male
# 3    2021-09-01         1     12131415  Female

# %%
dff=pd.read_csv('/home/sikshana/sw/leaves/leaveapp/foo.csv')
dff
# Out:
#    Unnamed: 0  employee_number  password employee_name  role  rollover  \
# 0           0            12345  20190703        Mahesh     1        77
# 1           1             5678  20190703     Archana S     0        66
# 2           2            91011  20190703          Ravi     1        55
# 3           3         12131415  20190703     Archana J     0        44
#
#             region lm_start_date  approver  approver_id  Gender  \
# 0  South Karnataka    2021-06-01         1     12131415    Male
# 1      Maharashtra    2021-07-01         1     12131415  Female
# 2          Gujarat    2021-08-01         1     12131415    Male
# 3  North Karnataka    2021-09-01         1     12131415  Female
#
#                                   token
# 0  6d5393d0-4e34-45f1-90cb-02b878aaae74
# 1  ef597e39-ed0b-45d8-b550-ad0626908d4d
# 2  dd600ed2-ae4a-41a0-a905-0325af422c51
# 3  7639bd5a-9ce5-4af9-b40f-7d32ffc2c400

# %%
dfh=pd.read_csv('/home/sikshana/sw/leaves/leaveapp/holidays.csv')
dfh
# Out:
#              region        date              name
# 0  General Holidays  2022-08-15  Independence day
# 1  General Holidays  2022-10-02   Gandhi Jayanthi
# 2  General Holidays  2022-01-26      Republic day
# 3   South Karnataka  2022-07-12      Ayudha Pooja
# 4   North Karnataka  2022-08-12        Sankranthi
# 5       Maharashtra  2022-09-12         Deepavali
# 6           Gujarat  2022-10-12         christmas
# 7        Tamil Nadu  2022-11-12      teachers day
# 8         Telangana  2022-11-12      teachers day

# %%
dfR=pd.read_csv('/home/sikshana/sw/leaves/leaveapp/Records.csv')
dfR
# Out:
#      employee_number  password       employee_name  role  rollover  \
# 0                266  20140601         Arun Kantha     1         0
# 1                273  20180901     Gangadharaiah D     1         0
# 2                294  20140601  Yallappa P Salunke     1         0
# 3                610  20181029      Basavaraja B.A     1         0
# 4                640  20211125             Thara S     1         0
# ..               ...       ...                 ...   ...       ...
# 134            31162  20140601           Ranjini M     0         3
# 135            32759  20140601         Kiran Kumar     0         9
# 136            40314  20140601        Rangaswamy K     0         4
# 137            44917  20140701         Bharath G S     0         9
# 138             8079  20211215       Kumara Naik V     1         0
#
#               region lm_start_date  approver  approver_id  Gender
# 0    South Karnataka    01/01/2022         0         2214    Male
# ...

# %%
dfre=pd.read_excel('/home/sikshana/sw/leaves/leaveapp/Records.xlsx', dtype={'employee_number': str,
                                                                             'approver_id': str })
dfre
# Out:
#     employee_number  password       employee_name  role  rollover  \
# 0             00266  20140601         Arun Kantha     1         0
# 1             00273  20180901     Gangadharaiah D     1         0
# 2             00294  20140601  Yallappa P Salunke     1         0
# 3             00610  20181029      Basavaraja B.A     1         0
# 4             00640  20211125             Thara S     1         0
# ..              ...       ...                 ...   ...       ...
# 134           31162  20140601           Ranjini M     0         3
# 135           32759  20140601         Kiran Kumar     0         9
# 136           40314  20140601        Rangaswamy K     0         4
# 137           44917  20140701         Bharath G S     0         9
# 138           08079  20211215       Kumara Naik V     1         0
#
#               region lm_start_date  approver approver_id  Gender
# 0    South Karnataka    2022-01-01         0       02214    Male
# ...

# %%
dfre.loc[dfre['employee_name']=='Vedamurthy G']
# Out:
#    employee_number  password employee_name  role  rollover           region  \
# 66           05932  20180901  Vedamurthy G     1         0  South Karnataka
#
#    lm_start_date  approver approver_id Gender
# 66    2022-01-01         0       00273   Male

# %%
dfre.region.unique()
# Out:
# array(['South Karnataka', 'North Karnataka', 'Maharashtra', 'Telangana',
#        'Tamil Nadu', 'Andhra Pradesh', 'Gujarat'], dtype=object)

# %%
dfre.loc[dfre['employee_number'] == '03300']
# Out:
#    employee_number  password employee_name  role  rollover           region  \
# 45           03300  20190801     Pooja G R     1         0  South Karnataka
#
#    lm_start_date  approver approver_id  Gender
# 45    2022-01-01         0       15322  Female
